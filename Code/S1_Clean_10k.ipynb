# %%
import os
import re
import json
import requests
import time
from bs4 import BeautifulSoup
from requests.exceptions import RequestException, ConnectionError, HTTPError

# SEC requires a valid User-Agent header
HEADERS = {
    'User-Agent': 'UC Davis Analytics/1.0 (wenjunsong2002@outlook.com)',
    'Accept': 'application/json, text/html'
}

# %%
def download_file(url, dest_path, retries=3, delay=5):
    """
    Download a file from a URL to a local path with retries on failure.
    """
    for attempt in range(1, retries + 1):
        try:
            resp = requests.get(url, headers=HEADERS, timeout=15)
            resp.raise_for_status()
            with open(dest_path, 'wb') as f:
                f.write(resp.content)
            print(f"Downloaded: {url} -> {dest_path}")
            return
        except (ConnectionError, HTTPError, RequestException) as e:
            print(f"Attempt {attempt} failed for {url}: {e}")
            if attempt < retries:
                time.sleep(delay)
    raise RuntimeError(f"Failed to download file after {retries} attempts: {url}")

# %%
def parse_index_for_xml(index_url):
    """
    Fetch the EDGAR index page and parse out the XML filename ending with _htm.xml.
    """
    try:
        resp = requests.get(index_url, headers=HEADERS, timeout=15)
        resp.raise_for_status()
    except (ConnectionError, HTTPError, RequestException) as e:
        raise RuntimeError(f"Failed to load index page: {e}")

    soup = BeautifulSoup(resp.text, 'html.parser')
    link = soup.find('a', href=re.compile(r'.+_htm\.xml$'))
    if not link:
        raise ValueError('Could not find XML file link on index page')
    xml_filename = os.path.basename(link['href'])
    base = index_url.rsplit('/', 1)[0]
    xml_url = f"{base}/{xml_filename}"
    return xml_url, xml_filename

# %%
def clean_text(content):
    """
    Normalize whitespace in text.
    """
    return re.sub(r"\s+", " ", content).strip()

# %%
def extract_item_robust(text, start_label, end_label):
    """
    Extract text between two markers, skipping the first occurrence if it's in the TOC.
    """
    pattern_start = re.compile(start_label, re.IGNORECASE)
    pattern_end = re.compile(end_label, re.IGNORECASE)
    starts = list(pattern_start.finditer(text))
    if not starts:
        return ''
    start_idx = starts[1].start() if len(starts) > 1 else starts[0].start()
    end_match = pattern_end.search(text[start_idx:])
    if not end_match:
        return text[start_idx:].strip()
    end_idx = start_idx + end_match.start()
    return text[start_idx:end_idx].strip()

# %%
def extract_sections(text):
    return {
        'item1': extract_item_robust(text, r'Item 1\.?\s+Business', r'Item 1A\.?\s+Risk Factors'),
        'item1a': extract_item_robust(text, r'Item 1A\.?\s+Risk Factors', r'Item 1B\.?\s+Unresolved Staff Comments'),
        'item7': extract_item_robust(text, r'Item 7\.?\s+Management.*?Discussion.*?Financial.*?Condition', r'Item 7A\.?\s+Quantitative and Qualitative'),
        'item7a': extract_item_robust(text, r'Item 7A\.?\s+Quantitative and Qualitative', r'Item 8\.?\s+Financial Statements')
    }

# %%
def fetch_cusip_from_submissions(cik):
    cik_padded = f"{int(cik):010d}"
    url = f"https://data.sec.gov/submissions/CIK{cik_padded}.json"
    try:
        resp = requests.get(url, headers=HEADERS, timeout=15)
        resp.raise_for_status()
        data = resp.json()
        cusips = data.get('filings', {}).get('recent', {}).get('cusip', [])
        if cusips:
            return cusips[0][:6]
    except Exception as e:
        print(f"Failed to fetch CUSIP from submissions JSON: {e}")
    return ''

# %%
## Old
def fetch_cusip_from_sc13ga(cik):
    """
    Find CUSIP6 by parsing the latest SC 13G/A beneficial ownership report.
    The CUSIP number often appears before the phrase '(CUSIP Number)'.
    """
    overrides = {
        "0000019617": "46625H",   # JPMorgan Chase & Co.
        "0000104169": "931142",   # Walmart Inc.
        "0000034088": "30231G"    # Exxon Mobil Corp.
    }
    if cik in overrides:
        return overrides[cik]
    cik_padded = f"{int(cik):010d}"
    subs_url = f"https://data.sec.gov/submissions/CIK{cik_padded}.json"
    try:
        resp = requests.get(subs_url, headers=HEADERS, timeout=15)
        resp.raise_for_status()
        data = resp.json()
        forms = data['filings']['recent']['form']
        accs = data['filings']['recent']['accessionNumber']
        docs = data['filings']['recent']['primaryDocument']
        cik_no_zero = cik.lstrip('0')
        for form, acc, doc in zip(forms, accs, docs):
            if form.startswith('SC 13G'):
                acc_no_dash = acc.replace('-', '')
                url = f"https://www.sec.gov/Archives/edgar/data/{cik_no_zero}/{acc_no_dash}/{doc}"
                r = requests.get(url, headers=HEADERS, timeout=15)
                r.raise_for_status()
                text = r.text
                # first attempt: number before '(CUSIP Number)'
                m = re.search(
                    r"([0-9A-Za-z\-]{6,11})\s*\(\s*CUSIP\s*Number\s*\)",
                    text,
                    re.IGNORECASE)
                # 2) Fallback to “CUSIP NO. 123456789”
                if not m:
                    m = re.search(
                        r"CUSIP\s*NO\.?\s*([0-9A-Za-z\-]{6,11})",
                        text,
                        re.IGNORECASE)
                # 3) Final fallback to “CUSIP Number:  123456789”
                if not m:
                    m = re.search(
                        r"CUSIP\s*Number:?\s*([0-9A-Za-z\-]{6,11})",
                        text,
                        re.IGNORECASE)
                if m:
                    raw = m.group(1)              # e.g. "931142-10-3" or "46625H100"
                    clean = raw.replace("-", "")  # remove any dashes
                    return clean[:6]              # take first 6 characters
    except Exception as e:
        print(f"Failed to fetch CUSIP from SC 13G/A: {e}")
    return ''

# %%
def extract_metadata_from_xml(xml_path):
    """
    Parse the XBRL XML file for metadata: company name, CIK, CUSIP6.
    Falls back to submissions JSON or SC 13G/A if CUSIP absent.
    """
    try:
        with open(xml_path, 'r', encoding='utf-8') as f:
            xml_soup = BeautifulSoup(f, 'lxml-xml')
        name_tag = xml_soup.find('dei:EntityRegistrantName') or xml_soup.find('EntityRegistrantName')
        cik_tag = xml_soup.find('dei:EntityCentralIndexKey') or xml_soup.find('EntityCentralIndexKey')
        cusip_tag = xml_soup.find('dei:CusipNumber') or xml_soup.find('CusipNumber')
        names = name_tag.text.strip() if name_tag else ''
        cik = cik_tag.text.strip() if cik_tag else ''
        cusip6 = cusip_tag.text.strip()[:6] if cusip_tag else ''
        if not cusip6 and cik:
            cusip6 = fetch_cusip_from_submissions(cik)
        if not cusip6 and cik:
            cusip6 = fetch_cusip_from_sc13ga(cik)

        
        return { 'names': names, 'cik': cik, 'cusip6': cusip6 }
    except Exception as e:
        print(f"Failed to parse XML metadata: {e}")
        return { 'names': '', 'cik': '', 'cusip6': '' }

# %%
def extract_and_clean(index_url, output_json='ntap_10k_cleaned.json'):
    try:
        xml_url, xml_filename = parse_index_for_xml(index_url)
    except Exception as e:
        print(f"Error parsing index page: {e}")
        return
    os.makedirs('download', exist_ok=True)
    xml_path = os.path.join('download', xml_filename)
    try:
        download_file(xml_url, xml_path)
    except Exception as e:
        print(f"Error downloading XML file: {e}")
        return
    htm_filename = xml_filename.replace('_htm.xml', '.htm')
    htm_url = xml_url.replace(xml_filename, htm_filename)
    htm_path = os.path.join('download', htm_filename)
    try:
        download_file(htm_url, htm_path)
    except Exception as e:
        print(f"Error downloading HTML file: {e}")
        return
    try:
        with open(htm_path, 'r', encoding='utf-8') as f:
            html = f.read()
        soup = BeautifulSoup(html, 'html.parser')
        full_text = soup.get_text(separator=' ')
        cleaned = clean_text(full_text)
    except Exception as e:
        print(f"Error parsing HTML text: {e}")
        return
    sections = extract_sections(cleaned)
    meta = extract_metadata_from_xml(xml_path)
    # Construct official iXBRL URL as source
    # xml_url like https://www.sec.gov/Archives/.../indexdir/filename_htm.xml
    # derive base archive path
    archive_prefix = xml_url.split('https://www.sec.gov')[-1].rsplit('/', 1)[0]
    ix_htm_url = f"https://www.sec.gov/ix?doc={archive_prefix}/{htm_filename}"
    meta['source'] = ix_htm_url
    # Build official iXBRL source URL for clickable link
    archive_path = xml_url.split('https://www.sec.gov')[-1].rsplit('/', 1)[0]
    ix_htm_url = f"https://www.sec.gov/ix?doc={archive_path}/{htm_filename}"
    meta['source'] = ix_htm_url
    result = { **meta, **sections }
    try:
        with open(output_json, 'w', encoding='utf-8') as f:
            json.dump(result, f, ensure_ascii=False, indent=2)
        print(f"Saved cleaned data to {output_json}")
    except Exception as e:
        print(f"Error saving JSON: {e}")

# %%
def get_cik_mapping():
    mapping_url = 'https://www.sec.gov/files/company_tickers.json'
    resp = requests.get(mapping_url, headers=HEADERS, timeout=15)
    resp.raise_for_status()
    data = resp.json()
    return {v['ticker']: v['cik_str'] for v in data.values()}

def find_10k_accessions_by_year(cik):
    padded = f"{int(cik):010d}"
    subs_url = f"https://data.sec.gov/submissions/CIK{padded}.json"
    resp = requests.get(subs_url, headers=HEADERS, timeout=15)
    resp.raise_for_status()
    data = resp.json()
    forms = data['filings']['recent']['form']
    accs = data['filings']['recent']['accessionNumber']
    dates = data['filings']['recent']['filingDate']
    
    year_map = {}
    for form, acc, date in zip(forms, accs, dates):
        if form == '10-K':
            year = date[:4]
            year_map.setdefault(year, []).append(acc)
    return year_map

# %%
if __name__ == '__main__':
    tickers = [
        'AAPL', 'JPM', 'JNJ', 'XOM', 'WMT',
        'TSLA', 'PLD', 'BA', 'NFLX', 'NVDA'
    ]
    cik_map = get_cik_mapping()

    for ticker in tickers:
        cik = cik_map.get(ticker)
        if not cik:
            print(f"CIK not found for ticker {ticker}, skipping.")
            continue
        try:
            year_to_accessions = find_10k_accessions_by_year(cik)
            for year, accessions in sorted(year_to_accessions.items()):
                for acc in accessions:
                    acc_nodash = acc.replace('-', '')
                    index_filename = f"{acc}-index.html"
                    index_url = f"https://www.sec.gov/Archives/edgar/data/{int(cik)}/{acc_nodash}/{index_filename}"
                    out_dir = f"output/{ticker}"
                    os.makedirs(out_dir, exist_ok=True)
                    out_json = f"{out_dir}/{ticker}_10k_{year}.json"
                    print(f"\nProcessing {ticker} {year}: {index_url}")
                    extract_and_clean(index_url, output_json=out_json)
        except Exception as e:
            print(f"Failed processing {ticker}: {e}")
# Out:
# Processing AAPL 2014: https://www.sec.gov/Archives/edgar/data/320193/000119312514383437/0001193125-14-383437-index.html
# Error parsing index page: Could not find XML file link on index page
#
# Processing AAPL 2015: https://www.sec.gov/Archives/edgar/data/320193/000119312515356351/0001193125-15-356351-index.html
# Error parsing index page: Could not find XML file link on index page
#
# Processing AAPL 2016: https://www.sec.gov/Archives/edgar/data/320193/000162828016020309/0001628280-16-020309-index.html
# Error parsing index page: Could not find XML file link on index page
#
# Processing AAPL 2017: https://www.sec.gov/Archives/edgar/data/320193/000032019317000070/0000320193-17-000070-index.html
# Error parsing index page: Could not find XML file link on index page
#
# Processing AAPL 2018: https://www.sec.gov/Archives/edgar/data/320193/000032019318000145/0000320193-18-000145-index.html
# Error parsing index page: Could not find XML file link on index page
#
# Processing AAPL 2019: https://www.sec.gov/Archives/edgar/data/320193/000032019319000119/0000320193-19-000119-index.html
# Downloaded: https://www.sec.gov/Archives/edgar/data/320193/000032019319000119/a10-k20199282019_htm.xml -> download/a10-k20199282019_htm.xml
# Downloaded: https://www.sec.gov/Archives/edgar/data/320193/000032019319000119/a10-k20199282019.htm -> download/a10-k20199282019.htm
# Saved cleaned data to output/AAPL/AAPL_10k_2019.json
#
# Processing AAPL 2020: https://www.sec.gov/Archives/edgar/data/320193/000032019320000096/0000320193-20-000096-index.html
# Downloaded: https://www.sec.gov/Archives/edgar/data/320193/000032019320000096/aapl-20200926_htm.xml -> download/aapl-20200926_htm.xml
# Downloaded: https://www.sec.gov/Archives/edgar/data/320193/000032019320000096/aapl-20200926.htm -> download/aapl-20200926.htm
# Saved cleaned data to output/AAPL/AAPL_10k_2020.json
#
# Processing AAPL 2021: https://www.sec.gov/Archives/edgar/data/320193/000032019321000105/0000320193-21-000105-index.html
# Downloaded: https://www.sec.gov/Archives/edgar/data/320193/000032019321000105/aapl-20210925_htm.xml -> download/aapl-20210925_htm.xml
# Downloaded: https://www.sec.gov/Archives/edgar/data/320193/000032019321000105/aapl-20210925.htm -> download/aapl-20210925.htm
# Saved cleaned data to output/AAPL/AAPL_10k_2021.json
#
# Processing AAPL 2022: https://www.sec.gov/Archives/edgar/data/320193/000032019322000108/0000320193-22-000108-index.html
# Downloaded: https://www.sec.gov/Archives/edgar/data/320193/000032019322000108/aapl-20220924_htm.xml -> download/aapl-20220924_htm.xml
# Downloaded: https://www.sec.gov/Archives/edgar/data/320193/000032019322000108/aapl-20220924.htm -> download/aapl-20220924.htm
# Saved cleaned data to output/AAPL/AAPL_10k_2022.json
#
# Processing AAPL 2023: https://www.sec.gov/Archives/edgar/data/320193/000032019323000106/0000320193-23-000106-index.html
# Downloaded: https://www.sec.gov/Archives/edgar/data/320193/000032019323000106/aapl-20230930_htm.xml -> download/aapl-20230930_htm.xml
# Downloaded: https://www.sec.gov/Archives/edgar/data/320193/000032019323000106/aapl-20230930.htm -> download/aapl-20230930.htm
# Saved cleaned data to output/AAPL/AAPL_10k_2023.json
#
# Processing AAPL 2024: https://www.sec.gov/Archives/edgar/data/320193/000032019324000123/0000320193-24-000123-index.html
# Downloaded: https://www.sec.gov/Archives/edgar/data/320193/000032019324000123/aapl-20240928_htm.xml -> download/aapl-20240928_htm.xml
# Downloaded: https://www.sec.gov/Archives/edgar/data/320193/000032019324000123/aapl-20240928.htm -> download/aapl-20240928.htm
# Saved cleaned data to output/AAPL/AAPL_10k_2024.json
#
# Processing JPM 2025: https://www.sec.gov/Archives/edgar/data/19617/000001961725000270/0000019617-25-000270-index.html
# Downloaded: https://www.sec.gov/Archives/edgar/data/19617/000001961725000270/jpm-20241231_htm.xml -> download/jpm-20241231_htm.xml
# Downloaded: https://www.sec.gov/Archives/edgar/data/19617/000001961725000270/jpm-20241231.htm -> download/jpm-20241231.htm
# Saved cleaned data to output/JPM/JPM_10k_2025.json
#
# Processing JNJ 2017: https://www.sec.gov/Archives/edgar/data/200406/000020040617000006/0000200406-17-000006-index.html
# Error parsing index page: Could not find XML file link on index page
#
# Processing JNJ 2018: https://www.sec.gov/Archives/edgar/data/200406/000020040618000005/0000200406-18-000005-index.html
# Error parsing index page: Could not find XML file link on index page
#
# Processing JNJ 2019: https://www.sec.gov/Archives/edgar/data/200406/000020040619000009/0000200406-19-000009-index.html
# Error parsing index page: Could not find XML file link on index page
#
# Processing JNJ 2020: https://www.sec.gov/Archives/edgar/data/200406/000020040620000010/0000200406-20-000010-index.html
# Downloaded: https://www.sec.gov/Archives/edgar/data/200406/000020040620000010/form10-k20191229_htm.xml -> download/form10-k20191229_htm.xml
# Downloaded: https://www.sec.gov/Archives/edgar/data/200406/000020040620000010/form10-k20191229.htm -> download/form10-k20191229.htm
# Saved cleaned data to output/JNJ/JNJ_10k_2020.json
#
# Processing JNJ 2021: https://www.sec.gov/Archives/edgar/data/200406/000020040621000008/0000200406-21-000008-index.html
# Downloaded: https://www.sec.gov/Archives/edgar/data/200406/000020040621000008/jnj-20210103_htm.xml -> download/jnj-20210103_htm.xml
# Downloaded: https://www.sec.gov/Archives/edgar/data/200406/000020040621000008/jnj-20210103.htm -> download/jnj-20210103.htm
# Saved cleaned data to output/JNJ/JNJ_10k_2021.json
#
# Processing JNJ 2022: https://www.sec.gov/Archives/edgar/data/200406/000020040622000022/0000200406-22-000022-index.html
# Downloaded: https://www.sec.gov/Archives/edgar/data/200406/000020040622000022/jnj-20220102_htm.xml -> download/jnj-20220102_htm.xml
# Downloaded: https://www.sec.gov/Archives/edgar/data/200406/000020040622000022/jnj-20220102.htm -> download/jnj-20220102.htm
# Saved cleaned data to output/JNJ/JNJ_10k_2022.json
#
# Processing JNJ 2023: https://www.sec.gov/Archives/edgar/data/200406/000020040623000016/0000200406-23-000016-index.html
# Downloaded: https://www.sec.gov/Archives/edgar/data/200406/000020040623000016/jnj-20230101_htm.xml -> download/jnj-20230101_htm.xml
# Downloaded: https://www.sec.gov/Archives/edgar/data/200406/000020040623000016/jnj-20230101.htm -> download/jnj-20230101.htm
# Saved cleaned data to output/JNJ/JNJ_10k_2023.json
#
# Processing JNJ 2024: https://www.sec.gov/Archives/edgar/data/200406/000020040624000013/0000200406-24-000013-index.html
# Downloaded: https://www.sec.gov/Archives/edgar/data/200406/000020040624000013/jnj-20231231_htm.xml -> download/jnj-20231231_htm.xml
# Downloaded: https://www.sec.gov/Archives/edgar/data/200406/000020040624000013/jnj-20231231.htm -> download/jnj-20231231.htm
# Saved cleaned data to output/JNJ/JNJ_10k_2024.json
#
# Processing JNJ 2025: https://www.sec.gov/Archives/edgar/data/200406/000020040625000038/0000200406-25-000038-index.html
# Downloaded: https://www.sec.gov/Archives/edgar/data/200406/000020040625000038/jnj-20241229_htm.xml -> download/jnj-20241229_htm.xml
# Downloaded: https://www.sec.gov/Archives/edgar/data/200406/000020040625000038/jnj-20241229.htm -> download/jnj-20241229.htm
# Saved cleaned data to output/JNJ/JNJ_10k_2025.json
#
# Processing XOM 2019: https://www.sec.gov/Archives/edgar/data/34088/000003408819000010/0000034088-19-000010-index.html
# Error parsing index page: Could not find XML file link on index page
#
# Processing XOM 2020: https://www.sec.gov/Archives/edgar/data/34088/000003408820000016/0000034088-20-000016-index.html
# Downloaded: https://www.sec.gov/Archives/edgar/data/34088/000003408820000016/xom10k2019_htm.xml -> download/xom10k2019_htm.xml
# Downloaded: https://www.sec.gov/Archives/edgar/data/34088/000003408820000016/xom10k2019.htm -> download/xom10k2019.htm
# Saved cleaned data to output/XOM/XOM_10k_2020.json
#
# Processing XOM 2021: https://www.sec.gov/Archives/edgar/data/34088/000003408821000012/0000034088-21-000012-index.html
# Downloaded: https://www.sec.gov/Archives/edgar/data/34088/000003408821000012/xom-20201231_htm.xml -> download/xom-20201231_htm.xml
# Downloaded: https://www.sec.gov/Archives/edgar/data/34088/000003408821000012/xom-20201231.htm -> download/xom-20201231.htm
# Saved cleaned data to output/XOM/XOM_10k_2021.json
#
# Processing XOM 2022: https://www.sec.gov/Archives/edgar/data/34088/000003408822000011/0000034088-22-000011-index.html
# Downloaded: https://www.sec.gov/Archives/edgar/data/34088/000003408822000011/xom-20211231_htm.xml -> download/xom-20211231_htm.xml
# Downloaded: https://www.sec.gov/Archives/edgar/data/34088/000003408822000011/xom-20211231.htm -> download/xom-20211231.htm
# Saved cleaned data to output/XOM/XOM_10k_2022.json
#
# Processing XOM 2023: https://www.sec.gov/Archives/edgar/data/34088/000003408823000020/0000034088-23-000020-index.html
# Downloaded: https://www.sec.gov/Archives/edgar/data/34088/000003408823000020/xom-20221231_htm.xml -> download/xom-20221231_htm.xml
# Downloaded: https://www.sec.gov/Archives/edgar/data/34088/000003408823000020/xom-20221231.htm -> download/xom-20221231.htm
# Saved cleaned data to output/XOM/XOM_10k_2023.json
#
# Processing XOM 2024: https://www.sec.gov/Archives/edgar/data/34088/000003408824000018/0000034088-24-000018-index.html
# Downloaded: https://www.sec.gov/Archives/edgar/data/34088/000003408824000018/xom-20231231_htm.xml -> download/xom-20231231_htm.xml
# Downloaded: https://www.sec.gov/Archives/edgar/data/34088/000003408824000018/xom-20231231.htm -> download/xom-20231231.htm
# Saved cleaned data to output/XOM/XOM_10k_2024.json
#
# Processing XOM 2025: https://www.sec.gov/Archives/edgar/data/34088/000003408825000010/0000034088-25-000010-index.html
# Downloaded: https://www.sec.gov/Archives/edgar/data/34088/000003408825000010/xom-20241231_htm.xml -> download/xom-20241231_htm.xml
# Downloaded: https://www.sec.gov/Archives/edgar/data/34088/000003408825000010/xom-20241231.htm -> download/xom-20241231.htm
# Saved cleaned data to output/XOM/XOM_10k_2025.json
#
# Processing WMT 2022: https://www.sec.gov/Archives/edgar/data/104169/000010416922000012/0000104169-22-000012-index.html
# Downloaded: https://www.sec.gov/Archives/edgar/data/104169/000010416922000012/wmt-20220131_htm.xml -> download/wmt-20220131_htm.xml
# Downloaded: https://www.sec.gov/Archives/edgar/data/104169/000010416922000012/wmt-20220131.htm -> download/wmt-20220131.htm
# Saved cleaned data to output/WMT/WMT_10k_2022.json
#
# Processing WMT 2023: https://www.sec.gov/Archives/edgar/data/104169/000010416923000020/0000104169-23-000020-index.html
# Downloaded: https://www.sec.gov/Archives/edgar/data/104169/000010416923000020/wmt-20230131_htm.xml -> download/wmt-20230131_htm.xml
# Downloaded: https://www.sec.gov/Archives/edgar/data/104169/000010416923000020/wmt-20230131.htm -> download/wmt-20230131.htm
# Saved cleaned data to output/WMT/WMT_10k_2023.json
#
# Processing WMT 2024: https://www.sec.gov/Archives/edgar/data/104169/000010416924000056/0000104169-24-000056-index.html
# Downloaded: https://www.sec.gov/Archives/edgar/data/104169/000010416924000056/wmt-20240131_htm.xml -> download/wmt-20240131_htm.xml
# Downloaded: https://www.sec.gov/Archives/edgar/data/104169/000010416924000056/wmt-20240131.htm -> download/wmt-20240131.htm
# Saved cleaned data to output/WMT/WMT_10k_2024.json
#
# Processing WMT 2025: https://www.sec.gov/Archives/edgar/data/104169/000010416925000021/0000104169-25-000021-index.html
# Downloaded: https://www.sec.gov/Archives/edgar/data/104169/000010416925000021/wmt-20250131_htm.xml -> download/wmt-20250131_htm.xml
# Downloaded: https://www.sec.gov/Archives/edgar/data/104169/000010416925000021/wmt-20250131.htm -> download/wmt-20250131.htm
# Saved cleaned data to output/WMT/WMT_10k_2025.json
#
# Processing TSLA 2017: https://www.sec.gov/Archives/edgar/data/1318605/000156459017003118/0001564590-17-003118-index.html
# Error parsing index page: Could not find XML file link on index page
#
# Processing TSLA 2018: https://www.sec.gov/Archives/edgar/data/1318605/000156459018002956/0001564590-18-002956-index.html
# Error parsing index page: Could not find XML file link on index page
#
# Processing TSLA 2019: https://www.sec.gov/Archives/edgar/data/1318605/000156459019003165/0001564590-19-003165-index.html
# Error parsing index page: Could not find XML file link on index page
#
# Processing TSLA 2020: https://www.sec.gov/Archives/edgar/data/1318605/000156459020004475/0001564590-20-004475-index.html
# Downloaded: https://www.sec.gov/Archives/edgar/data/1318605/000156459020004475/tsla-10k_20191231_htm.xml -> download/tsla-10k_20191231_htm.xml
# Downloaded: https://www.sec.gov/Archives/edgar/data/1318605/000156459020004475/tsla-10k_20191231.htm -> download/tsla-10k_20191231.htm
# Saved cleaned data to output/TSLA/TSLA_10k_2020.json
#
# Processing TSLA 2021: https://www.sec.gov/Archives/edgar/data/1318605/000156459021004599/0001564590-21-004599-index.html
# Downloaded: https://www.sec.gov/Archives/edgar/data/1318605/000156459021004599/tsla-10k_20201231_htm.xml -> download/tsla-10k_20201231_htm.xml
# Downloaded: https://www.sec.gov/Archives/edgar/data/1318605/000156459021004599/tsla-10k_20201231.htm -> download/tsla-10k_20201231.htm
# Saved cleaned data to output/TSLA/TSLA_10k_2021.json
#
# Processing TSLA 2022: https://www.sec.gov/Archives/edgar/data/1318605/000095017022000796/0000950170-22-000796-index.html
# Downloaded: https://www.sec.gov/Archives/edgar/data/1318605/000095017022000796/tsla-20211231_htm.xml -> download/tsla-20211231_htm.xml
# Downloaded: https://www.sec.gov/Archives/edgar/data/1318605/000095017022000796/tsla-20211231.htm -> download/tsla-20211231.htm
# Saved cleaned data to output/TSLA/TSLA_10k_2022.json
#
# Processing TSLA 2023: https://www.sec.gov/Archives/edgar/data/1318605/000095017023001409/0000950170-23-001409-index.html
# Downloaded: https://www.sec.gov/Archives/edgar/data/1318605/000095017023001409/tsla-20221231_htm.xml -> download/tsla-20221231_htm.xml
# Downloaded: https://www.sec.gov/Archives/edgar/data/1318605/000095017023001409/tsla-20221231.htm -> download/tsla-20221231.htm
# Saved cleaned data to output/TSLA/TSLA_10k_2023.json
#
# Processing TSLA 2024: https://www.sec.gov/Archives/edgar/data/1318605/000162828024002390/0001628280-24-002390-index.html
# Downloaded: https://www.sec.gov/Archives/edgar/data/1318605/000162828024002390/tsla-20231231_htm.xml -> download/tsla-20231231_htm.xml
# Downloaded: https://www.sec.gov/Archives/edgar/data/1318605/000162828024002390/tsla-20231231.htm -> download/tsla-20231231.htm
# Saved cleaned data to output/TSLA/TSLA_10k_2024.json
#
# Processing TSLA 2025: https://www.sec.gov/Archives/edgar/data/1318605/000162828025003063/0001628280-25-003063-index.html
# Downloaded: https://www.sec.gov/Archives/edgar/data/1318605/000162828025003063/tsla-20241231_htm.xml -> download/tsla-20241231_htm.xml
# Downloaded: https://www.sec.gov/Archives/edgar/data/1318605/000162828025003063/tsla-20241231.htm -> download/tsla-20241231.htm
# Saved cleaned data to output/TSLA/TSLA_10k_2025.json
#
# Processing PLD 2019: https://www.sec.gov/Archives/edgar/data/1045609/000156459019002872/0001564590-19-002872-index.html
# Error parsing index page: Could not find XML file link on index page
#
# Processing PLD 2020: https://www.sec.gov/Archives/edgar/data/1045609/000156459020004096/0001564590-20-004096-index.html
# Downloaded: https://www.sec.gov/Archives/edgar/data/1045609/000156459020004096/pld-10k_20191231_htm.xml -> download/pld-10k_20191231_htm.xml
# Downloaded: https://www.sec.gov/Archives/edgar/data/1045609/000156459020004096/pld-10k_20191231.htm -> download/pld-10k_20191231.htm
# Saved cleaned data to output/PLD/PLD_10k_2020.json
#
# Processing PLD 2021: https://www.sec.gov/Archives/edgar/data/1045609/000156459021005312/0001564590-21-005312-index.html
# Downloaded: https://www.sec.gov/Archives/edgar/data/1045609/000156459021005312/pld-10k_20201231_htm.xml -> download/pld-10k_20201231_htm.xml
# Downloaded: https://www.sec.gov/Archives/edgar/data/1045609/000156459021005312/pld-10k_20201231.htm -> download/pld-10k_20201231.htm
# Saved cleaned data to output/PLD/PLD_10k_2021.json
#
# Processing PLD 2022: https://www.sec.gov/Archives/edgar/data/1045609/000156459022004436/0001564590-22-004436-index.html
# Downloaded: https://www.sec.gov/Archives/edgar/data/1045609/000156459022004436/pld-10k_20211231_htm.xml -> download/pld-10k_20211231_htm.xml
# Downloaded: https://www.sec.gov/Archives/edgar/data/1045609/000156459022004436/pld-10k_20211231.htm -> download/pld-10k_20211231.htm
# Saved cleaned data to output/PLD/PLD_10k_2022.json
#
# Processing PLD 2023: https://www.sec.gov/Archives/edgar/data/1045609/000156459023001902/0001564590-23-001902-index.html
# Downloaded: https://www.sec.gov/Archives/edgar/data/1045609/000156459023001902/pld-10k_20221231_htm.xml -> download/pld-10k_20221231_htm.xml
# Downloaded: https://www.sec.gov/Archives/edgar/data/1045609/000156459023001902/pld-10k_20221231.htm -> download/pld-10k_20221231.htm
# Saved cleaned data to output/PLD/PLD_10k_2023.json
#
# Processing PLD 2024: https://www.sec.gov/Archives/edgar/data/1045609/000095017024014539/0000950170-24-014539-index.html
# Downloaded: https://www.sec.gov/Archives/edgar/data/1045609/000095017024014539/pld-20231231_htm.xml -> download/pld-20231231_htm.xml
# Downloaded: https://www.sec.gov/Archives/edgar/data/1045609/000095017024014539/pld-20231231.htm -> download/pld-20231231.htm
# Saved cleaned data to output/PLD/PLD_10k_2024.json
#
# Processing PLD 2025: https://www.sec.gov/Archives/edgar/data/1045609/000095017025021272/0000950170-25-021272-index.html
# Downloaded: https://www.sec.gov/Archives/edgar/data/1045609/000095017025021272/pld-20241231_htm.xml -> download/pld-20241231_htm.xml
# Downloaded: https://www.sec.gov/Archives/edgar/data/1045609/000095017025021272/pld-20241231.htm -> download/pld-20241231.htm
# Saved cleaned data to output/PLD/PLD_10k_2025.json
#
# Processing BA 2019: https://www.sec.gov/Archives/edgar/data/12927/000001292719000010/0000012927-19-000010-index.html
# Downloaded: https://www.sec.gov/Archives/edgar/data/12927/000001292719000010/a201812dec3110k_htm.xml -> download/a201812dec3110k_htm.xml
# Downloaded: https://www.sec.gov/Archives/edgar/data/12927/000001292719000010/a201812dec3110k.htm -> download/a201812dec3110k.htm
# Saved cleaned data to output/BA/BA_10k_2019.json
#
# Processing BA 2020: https://www.sec.gov/Archives/edgar/data/12927/000001292720000014/0000012927-20-000014-index.html
# Downloaded: https://www.sec.gov/Archives/edgar/data/12927/000001292720000014/a201912dec3110k_htm.xml -> download/a201912dec3110k_htm.xml
# Downloaded: https://www.sec.gov/Archives/edgar/data/12927/000001292720000014/a201912dec3110k.htm -> download/a201912dec3110k.htm
# Saved cleaned data to output/BA/BA_10k_2020.json
#
# Processing BA 2021: https://www.sec.gov/Archives/edgar/data/12927/000001292721000011/0000012927-21-000011-index.html
# Downloaded: https://www.sec.gov/Archives/edgar/data/12927/000001292721000011/ba-20201231_htm.xml -> download/ba-20201231_htm.xml
# Downloaded: https://www.sec.gov/Archives/edgar/data/12927/000001292721000011/ba-20201231.htm -> download/ba-20201231.htm
# Saved cleaned data to output/BA/BA_10k_2021.json
#
# Processing BA 2022: https://www.sec.gov/Archives/edgar/data/12927/000001292722000010/0000012927-22-000010-index.html
# Downloaded: https://www.sec.gov/Archives/edgar/data/12927/000001292722000010/ba-20211231_htm.xml -> download/ba-20211231_htm.xml
# Downloaded: https://www.sec.gov/Archives/edgar/data/12927/000001292722000010/ba-20211231.htm -> download/ba-20211231.htm
# Saved cleaned data to output/BA/BA_10k_2022.json
#
# Processing BA 2023: https://www.sec.gov/Archives/edgar/data/12927/000001292723000007/0000012927-23-000007-index.html
# Downloaded: https://www.sec.gov/Archives/edgar/data/12927/000001292723000007/ba-20221231_htm.xml -> download/ba-20221231_htm.xml
# Downloaded: https://www.sec.gov/Archives/edgar/data/12927/000001292723000007/ba-20221231.htm -> download/ba-20221231.htm
# Saved cleaned data to output/BA/BA_10k_2023.json
#
# Processing BA 2024: https://www.sec.gov/Archives/edgar/data/12927/000001292724000010/0000012927-24-000010-index.html
# Downloaded: https://www.sec.gov/Archives/edgar/data/12927/000001292724000010/ba-20231231_htm.xml -> download/ba-20231231_htm.xml
# Downloaded: https://www.sec.gov/Archives/edgar/data/12927/000001292724000010/ba-20231231.htm -> download/ba-20231231.htm
# Saved cleaned data to output/BA/BA_10k_2024.json
#
# Processing BA 2025: https://www.sec.gov/Archives/edgar/data/12927/000001292725000015/0000012927-25-000015-index.html
# Downloaded: https://www.sec.gov/Archives/edgar/data/12927/000001292725000015/ba-20241231_htm.xml -> download/ba-20241231_htm.xml
# Downloaded: https://www.sec.gov/Archives/edgar/data/12927/000001292725000015/ba-20241231.htm -> download/ba-20241231.htm
# Saved cleaned data to output/BA/BA_10k_2025.json
#
# Processing NFLX 2022: https://www.sec.gov/Archives/edgar/data/1065280/000106528022000036/0001065280-22-000036-index.html
# Downloaded: https://www.sec.gov/Archives/edgar/data/1065280/000106528022000036/nflx-20211231_htm.xml -> download/nflx-20211231_htm.xml
# Downloaded: https://www.sec.gov/Archives/edgar/data/1065280/000106528022000036/nflx-20211231.htm -> download/nflx-20211231.htm
# Saved cleaned data to output/NFLX/NFLX_10k_2022.json
#
# Processing NFLX 2023: https://www.sec.gov/Archives/edgar/data/1065280/000106528023000035/0001065280-23-000035-index.html
# Downloaded: https://www.sec.gov/Archives/edgar/data/1065280/000106528023000035/nflx-20221231_htm.xml -> download/nflx-20221231_htm.xml
# Downloaded: https://www.sec.gov/Archives/edgar/data/1065280/000106528023000035/nflx-20221231.htm -> download/nflx-20221231.htm
# Saved cleaned data to output/NFLX/NFLX_10k_2023.json
#
# Processing NFLX 2024: https://www.sec.gov/Archives/edgar/data/1065280/000106528024000030/0001065280-24-000030-index.html
# Downloaded: https://www.sec.gov/Archives/edgar/data/1065280/000106528024000030/nflx-20231231_htm.xml -> download/nflx-20231231_htm.xml
# Downloaded: https://www.sec.gov/Archives/edgar/data/1065280/000106528024000030/nflx-20231231.htm -> download/nflx-20231231.htm
# Saved cleaned data to output/NFLX/NFLX_10k_2024.json
#
# Processing NFLX 2025: https://www.sec.gov/Archives/edgar/data/1065280/000106528025000044/0001065280-25-000044-index.html
# Downloaded: https://www.sec.gov/Archives/edgar/data/1065280/000106528025000044/nflx-20241231_htm.xml -> download/nflx-20241231_htm.xml
# Downloaded: https://www.sec.gov/Archives/edgar/data/1065280/000106528025000044/nflx-20241231.htm -> download/nflx-20241231.htm
# Saved cleaned data to output/NFLX/NFLX_10k_2025.json
#
# Processing NVDA 2018: https://www.sec.gov/Archives/edgar/data/1045810/000104581018000010/0001045810-18-000010-index.html
# Error parsing index page: Could not find XML file link on index page
#
# Processing NVDA 2019: https://www.sec.gov/Archives/edgar/data/1045810/000104581019000023/0001045810-19-000023-index.html
# Error parsing index page: Could not find XML file link on index page
#
# Processing NVDA 2020: https://www.sec.gov/Archives/edgar/data/1045810/000104581020000010/0001045810-20-000010-index.html
# Downloaded: https://www.sec.gov/Archives/edgar/data/1045810/000104581020000010/nvda-2020x10k_htm.xml -> download/nvda-2020x10k_htm.xml
# Downloaded: https://www.sec.gov/Archives/edgar/data/1045810/000104581020000010/nvda-2020x10k.htm -> download/nvda-2020x10k.htm
# Saved cleaned data to output/NVDA/NVDA_10k_2020.json
#
# Processing NVDA 2021: https://www.sec.gov/Archives/edgar/data/1045810/000104581021000010/0001045810-21-000010-index.html
# Downloaded: https://www.sec.gov/Archives/edgar/data/1045810/000104581021000010/nvda-20210131_htm.xml -> download/nvda-20210131_htm.xml
# Downloaded: https://www.sec.gov/Archives/edgar/data/1045810/000104581021000010/nvda-20210131.htm -> download/nvda-20210131.htm
# Saved cleaned data to output/NVDA/NVDA_10k_2021.json
#
# Processing NVDA 2022: https://www.sec.gov/Archives/edgar/data/1045810/000104581022000036/0001045810-22-000036-index.html
# Downloaded: https://www.sec.gov/Archives/edgar/data/1045810/000104581022000036/nvda-20220130_htm.xml -> download/nvda-20220130_htm.xml
# Downloaded: https://www.sec.gov/Archives/edgar/data/1045810/000104581022000036/nvda-20220130.htm -> download/nvda-20220130.htm
# Saved cleaned data to output/NVDA/NVDA_10k_2022.json
#
# Processing NVDA 2023: https://www.sec.gov/Archives/edgar/data/1045810/000104581023000017/0001045810-23-000017-index.html
# Downloaded: https://www.sec.gov/Archives/edgar/data/1045810/000104581023000017/nvda-20230129_htm.xml -> download/nvda-20230129_htm.xml
# Downloaded: https://www.sec.gov/Archives/edgar/data/1045810/000104581023000017/nvda-20230129.htm -> download/nvda-20230129.htm
# Saved cleaned data to output/NVDA/NVDA_10k_2023.json
#
# Processing NVDA 2024: https://www.sec.gov/Archives/edgar/data/1045810/000104581024000029/0001045810-24-000029-index.html
# Downloaded: https://www.sec.gov/Archives/edgar/data/1045810/000104581024000029/nvda-20240128_htm.xml -> download/nvda-20240128_htm.xml
# Downloaded: https://www.sec.gov/Archives/edgar/data/1045810/000104581024000029/nvda-20240128.htm -> download/nvda-20240128.htm
# Saved cleaned data to output/NVDA/NVDA_10k_2024.json
#
# Processing NVDA 2025: https://www.sec.gov/Archives/edgar/data/1045810/000104581025000023/0001045810-25-000023-index.html
# Downloaded: https://www.sec.gov/Archives/edgar/data/1045810/000104581025000023/nvda-20250126_htm.xml -> download/nvda-20250126_htm.xml
# Downloaded: https://www.sec.gov/Archives/edgar/data/1045810/000104581025000023/nvda-20250126.htm -> download/nvda-20250126.htm
# Saved cleaned data to output/NVDA/NVDA_10k_2025.json
